# %%
import pandas as pd

# %%
df = pd.read_csv('artist_output1.csv')

# %%
df['artist'].unique()
# Out:
# array(['Khalid', 'Rihanna', 'Roddy Ricch', 'Dua Lipa', 'Coldplay',
#        'Maroon 5', 'Ozuna', 'Maluma', 'Ed Sheeran', 'The Weeknd',
#        'Imagine Dragons', 'Beyonce', 'David Guetta', 'Ariana Grande',
#        'Eminem', 'Drake', 'Daddy Yankee', 'Taylor Swift', 'J Balvin',
#        'Justin Bieber', 'Selena Gomez', 'Halsey', 'Post Malone',
#        'Nicki Minaj', 'Shakira', 'Adele', 'Shawn Mendes',
#        'Camila Cabello', 'Bruno Mars', 'Billie Eilish', 'Marshmello',
#        'Calvin Harris'], dtype=object)

# %%
top_listened = pd.read_csv('top_monthly_listeners_feb_2020.csv')
top_followed = pd.read_csv('most_followed_feb_2020.csv')

top_artists = top_listened['Artist'].tolist()
top_artists.extend(top_followed['Artist'].tolist())
top_artists = list(set(top_artists))
len(top_artists)
# Out:
# 34

# %%
[artist for artist in top_artists if artist not in df['artist'].unique()]
# Out:
# ['Tones and I', 'Queen']

# %%
df = pd.read_csv('artist_output.csv')

# %%
[artist for artist in top_artists if artist not in df['artist'].unique()]
# Out:
# []

# %%
df
# Out:
#                album          artist  track_number                      id  \
# 0            Romance  Camila Cabello             3  0sHc1EEeOnmgjP6QmsR7px
# 1            Romance  Camila Cabello             4  3yOlyBJuViE2YSGn3nVE1K
# 2            Romance  Camila Cabello             7  0Q2kFlgnqusKAqCDpCKAIY
# 3            Romance  Camila Cabello             9  39jcp8zJH7nHWbB7Hr3sFJ
# 4            Romance  Camila Cabello            10  7jJ4y8hXMLMlGBu7Zm1XZj
# ...              ...             ...           ...                     ...
# 3590  Pies Descalzos         Shakira             9  4I0y9VniZ7JlDYthP8Vpo9
# 3591  Pies Descalzos         Shakira            10  6IGvaQ4aFBjy66TdUurIiA
# 3592  Pies Descalzos         Shakira            11  31NNxg7WYqs1bgRSFXgCf8
# 3593        Me Gusta         Shakira             1  5Xhqh4lwJPtMUTsdBztN1a
# 3594    Tutu (Remix)         Shakira             1  302I7g0l3jmAbzFu9WBCmu
#
#                          name                                   uri  \
# 0           Should've Said It  spotify:track:0sHc1EEeOnmgjP6QmsR7px
# 1     My Oh My (feat. DaBaby)  spotify:track:3yOlyBJuViE2YSGn3nVE1K
# 2     Bad Kind of Butterflies  spotify:track:0Q2kFlgnqusKAqCDpCKAIY
# 3               Feel It Twice  spotify:track:39jcp8zJH7nHWbB7Hr3sFJ
# 4                Dream of You  spotify:track:7jJ4y8hXMLMlGBu7Zm1XZj
# ...                       ...                                   ...
# 3590             Pienso en Ti  spotify:track:4I0y9VniZ7JlDYthP8Vpo9
# 3591      Donde Estas Corazon  spotify:track:6IGvaQ4aFBjy66TdUurIiA
# 3592       Se Quiere, Se Mata  spotify:track:31NNxg7WYqs1bgRSFXgCf8
# 3593                 Me Gusta  spotify:track:5Xhqh4lwJPtMUTsdBztN1a
# 3594             Tutu - Remix  spotify:track:302I7g0l3jmAbzFu9WBCmu
#
#       acousticness  danceability  energy  instrumentalness  liveness  \
# 0           0.0281         0.666  0.5490          0.000181    0.1360
# 1           0.0180         0.724  0.4910          0.000013    0.0887
# 2           0.5060         0.495  0.3080          0.000000    0.2470
# 3           0.8420         0.516  0.4360          0.000000    0.0901
# 4           0.2050         0.659  0.6630          0.000000    0.1050
# ...            ...           ...     ...               ...       ...
# 3590        0.9320         0.557  0.0271          0.000000    0.2480
# 3591        0.0635         0.743  0.7800          0.000000    0.1260
# 3592        0.0236         0.833  0.6070          0.000002    0.1540
# 3593        0.0559         0.775  0.6960          0.001840    0.1570
# 3594        0.3820         0.731  0.7630          0.000007    0.0754
#
#       loudness  speechiness    tempo  valence  popularity
# 0       -5.781       0.0269   98.014    0.596          70
# 1       -6.024       0.0296  105.046    0.383          92
# 2       -9.528       0.1410  108.484    0.273          68
# 3       -5.568       0.0283  132.070    0.376          67
# 4       -6.823       0.0811  140.013    0.333          67
# ...        ...          ...      ...      ...         ...
# 3590   -14.840       0.0394   99.648    0.229          56
# 3591    -9.212       0.0722  109.044    0.597          64
# 3592    -8.319       0.0327  118.003    0.668          53
# 3593    -5.184       0.0681   92.007    0.775          88
# 3594    -3.600       0.0433  154.111    0.865          76
#
# [3595 rows x 16 columns]
