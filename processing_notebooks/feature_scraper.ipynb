# %%
client_id = 'e195c8fc8d724d9cb1c301c45f5afe6b'
client_secret = '833ce97e263f47e7ae1a35313e1baec8'

# %%
import pandas as pd

# %%
top_listened = pd.read_csv('top_monthly_listeners_feb_2020.csv')
top_artists = top_listened['Artist'].tolist()
top_artists
# Out:
# ['Justin Bieber',
#  'Ed Sheeran',
#  'Billie Eilish',
#  'Camila Cabello',
#  'J Balvin',
#  'Khalid',
#  'Post Malone',
#  'Drake',
#  'Dua Lipa',
#  'The Weeknd',
#  'Nicki Minaj',
#  'Maroon 5',
#  'Eminem',
#  'Tones and I',
#  'Selena Gomez',
#  'Halsey',
#  'Shawn Mendes',
#  'Ariana Grande',
#  'Daddy Yankee',
#  'Roddy Ricch']

# %%
top_followed = pd.read_csv('most_followed_feb_2020.csv')
top_artists.extend(top_followed['Artist'].tolist())
top_artists = list(set(top_artists))
top_artists
# Out:
# ['Billie Eilish',
#  'Post Malone',
#  'Imagine Dragons',
#  'Eminem',
#  'Coldplay',
#  'The Weeknd',
#  'Shakira',
#  'Camila Cabello',
#  'Tones and I',
#  'Ozuna',
#  'David Guetta',
#  'Ed Sheeran',
#  'Adele',
#  'Maroon 5',
#  'Ariana Grande',
#  'Shawn Mendes',
#  'Dua Lipa',
#  'Bruno Mars',
#  'Maluma',
#  'Beyonce',
#  'Khalid',
#  'Roddy Ricch',
#  'Marshmello',
#  'Justin Bieber',
#  'Queen',
#  'Daddy Yankee',
#  'Selena Gomez',
#  'Drake',
#  'J Balvin',
#  'Nicki Minaj',
#  'Rihanna',
#  'Taylor Swift',
#  'Calvin Harris',
#  'Halsey']

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data

# %%
# client_id = {spotify client id}
# client_secret = {spotify secret id}
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API
name = "Tones and I" #chosen artist
result = sp.search(name, type='artist') #search query
result['artists']['items'][0]['uri']
# Out:
# 'spotify:artist:2NjfBq1NflQcKSeiDooVjY'

# %%
#Extract Artist's uri
artist_uri = result['artists']['items'][0]['uri']
#Pull all of the artist's albums
sp_albums = sp.artist_albums(artist_uri)
#Store artist's albums' names' and uris in separate lists
album_names = []
album_uris = []
for i in range(len(sp_albums['items'])):
    album_names.append(sp_albums['items'][i]['name'])
    album_uris.append(sp_albums['items'][i]['uri'])
    
album_names
album_uris
#Keep names and uris in same order to keep track of duplicate albums
# Out:
# ['spotify:album:7oVHtPdIA5kcxLLiCu2t7N',
#  'spotify:album:6MX2RQGxwnKc0iGlxTaWoS',
#  'spotify:album:4ozuVdO3D8DSLq6TVwz2JK',
#  'spotify:album:5fWGZ7dAPYdMslAjrPqfeQ',
#  'spotify:album:0UywfDKYlyiu1b38DRrzYD',
#  'spotify:album:49QPpqyxeTbzWHUJpZuUsC',
#  'spotify:album:2pJXQvY0YeDvVJ9gMU9G7j',
#  'spotify:album:1BYByciKxjYwhRSrWlEjWu',
#  'spotify:album:31IDBea3eEs57a0joX6TjN',
#  'spotify:album:7xXGPdbrUMXClnSMOIdTlW',
#  'spotify:album:3VBzESA5uPCoREP0cn7Eaa',
#  'spotify:album:3hScTVQsGp5ONBuMCADecb',
#  'spotify:album:73cLz4u3LHMboZoes6SNPb',
#  'spotify:album:2hPU01lHQ4hOYJG3RSjZkg',
#  'spotify:album:4HO0UhrFgDekt2akhIJBLt',
#  'spotify:album:3VF89zFeFR4e5tyP6GS8g4',
#  'spotify:album:2Qu4js8GY4Q1beCmFRR725',
#  'spotify:album:2KMgzDZgMXdMimq9Gp2Xln',
#  'spotify:album:1MGbP1L1OUl1Iot6lRuDci']

# %%
sp.artist_albums('spotify:artist:2NjfBq1NflQcKSeiDooVjY', album_type='album')
# Out:
# {'href': 'https://api.spotify.com/v1/artists/2NjfBq1NflQcKSeiDooVjY/albums?offset=0&limit=20&include_groups=album',
#  'items': [],
#  'limit': 20,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 0}

# %%
def albumSongs(uri):
    album = uri #assign album uri to a_name
    spotify_albums[album] = {} #Creates dictionary for that specific album
    #Create keys-values of empty lists inside nested dictionary for album
    spotify_albums[album]['album'] = [] #create empty list
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []
    tracks = sp.album_tracks(album) #pull data on album tracks
    for n in range(len(tracks['items'])): #for each song track
        spotify_albums[album]['album'].append(album_names[album_count]) #append album name tracked via album_count
        spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
        spotify_albums[album]['id'].append(tracks['items'][n]['id'])
        spotify_albums[album]['name'].append(tracks['items'][n]['name'])
        spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

# %%
spotify_albums = {}
album_count = 0
for i in album_uris: #each album
    albumSongs(i)
    print("Album " + str(album_names[album_count]) + " songs has been added to spotify_albums dictionary")
    album_count += 1 #Updates album count once all tracks have been added
# Out:
# Album Never Seen The Rain (Alternate Version) songs has been added to spotify_albums dictionary
# Album Never Seen The Rain (Alternate Version) songs has been added to spotify_albums dictionary
# Album Forever Young (triple j Like A Version) songs has been added to spotify_albums dictionary
# Album Dance Monkey (Stripped Back) songs has been added to spotify_albums dictionary
# Album Dance Monkey (Stripped Back) / Dance Monkey songs has been added to spotify_albums dictionary
# Album The Kids Are Coming - EP songs has been added to spotify_albums dictionary
# Album The Kids Are Coming songs has been added to spotify_albums dictionary
# Album Never Seen the Rain songs has been added to spotify_albums dictionary
# Album Dance Monkey songs has been added to spotify_albums dictionary
# Album Johnny Run Away songs has been added to spotify_albums dictionary
# Album 100 Greatest Number Ones (The Best No.1s Ever) songs has been added to spotify_albums dictionary
# Album Drive Time songs has been added to spotify_albums dictionary
# Album Today's Acoustic songs has been added to spotify_albums dictionary
# Album Today's Hits songs has been added to spotify_albums dictionary
# Album Today's Tracks songs has been added to spotify_albums dictionary
# Album 100 Greatest 10s: The Best Songs of Last Decade songs has been added to spotify_albums dictionary
# Album Playlist: Pop Hits songs has been added to spotify_albums dictionary
# Album Dance Monkey (Best Tracks of the Year) songs has been added to spotify_albums dictionary
# Album 100 Greatest 2019 Songs (Best Songs of the Year) songs has been added to spotify_albums dictionary

# %%
def audio_features(album):
    #Add new key-values to store audio features
    spotify_albums[album]['acousticness'] = []
    spotify_albums[album]['danceability'] = []
    spotify_albums[album]['energy'] = []
    spotify_albums[album]['instrumentalness'] = []
    spotify_albums[album]['liveness'] = []
    spotify_albums[album]['loudness'] = []
    spotify_albums[album]['speechiness'] = []
    spotify_albums[album]['tempo'] = []
    spotify_albums[album]['valence'] = []
    spotify_albums[album]['popularity'] = []
    #create a track counter
    track_count = 0
    for track in spotify_albums[album]['uri']:
        #pull audio features per track
        features = sp.audio_features(track)
        
        #Append to relevant key-value
        spotify_albums[album]['acousticness'].append(features[0]['acousticness'])
        spotify_albums[album]['danceability'].append(features[0]['danceability'])
        spotify_albums[album]['energy'].append(features[0]['energy'])
        spotify_albums[album]['instrumentalness'].append(features[0]['instrumentalness'])
        spotify_albums[album]['liveness'].append(features[0]['liveness'])
        spotify_albums[album]['loudness'].append(features[0]['loudness'])
        spotify_albums[album]['speechiness'].append(features[0]['speechiness'])
        spotify_albums[album]['tempo'].append(features[0]['tempo'])
        spotify_albums[album]['valence'].append(features[0]['valence'])
        #popularity is stored elsewhere
        pop = sp.track(track)
        spotify_albums[album]['popularity'].append(pop['popularity'])
        track_count+=1

# %%
import time
import numpy as np
sleep_min = 2
sleep_max = 5
start_time = time.time()
request_count = 0
for i in spotify_albums:
    audio_features(i)
    request_count += 1
    if request_count % 5 == 0:
        print(str(request_count) + " playlists completed")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# 5 playlists completed
# Loop #: 5
# Elapsed Time: 6.110550403594971 seconds
# 10 playlists completed
# Loop #: 10
# Elapsed Time: 11.596355438232422 seconds
# retrying ...3secs
# retrying ...2secs
# retrying ...3secs
# 15 playlists completed
# Loop #: 15
# Elapsed Time: 49.160359144210815 seconds
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs

# %%
dic_df = {}
dic_df['album'] = []
dic_df['track_number'] = []
dic_df['id'] = []
dic_df['name'] = []
dic_df['uri'] = []
dic_df['acousticness'] = []
dic_df['danceability'] = []
dic_df['energy'] = []
dic_df['instrumentalness'] = []
dic_df['liveness'] = []
dic_df['loudness'] = []
dic_df['speechiness'] = []
dic_df['tempo'] = []
dic_df['valence'] = []
dic_df['popularity'] = []
for album in spotify_albums: 
    for feature in spotify_albums[album]:
        dic_df[feature].extend(spotify_albums[album][feature])
        
len(dic_df['album'])
# Out:
# 375

# %%
df = pd.DataFrame.from_dict(dic_df)
df
# Out:
#                                                 album  track_number  \
# 0             Never Seen The Rain (Alternate Version)             1
# 1             Never Seen The Rain (Alternate Version)             2
# 2             Never Seen The Rain (Alternate Version)             1
# 3             Forever Young (triple j Like A Version)             1
# 4                        Dance Monkey (Stripped Back)             1
# ..                                                ...           ...
# 370  100 Greatest 2019 Songs (Best Songs of the Year)            46
# 371  100 Greatest 2019 Songs (Best Songs of the Year)            47
# 372  100 Greatest 2019 Songs (Best Songs of the Year)            48
# 373  100 Greatest 2019 Songs (Best Songs of the Year)            49
# 374  100 Greatest 2019 Songs (Best Songs of the Year)            50
#
#                          id                                     name  \
# 0    6MYNfMiLwCmA3bRdfzvfcs  Never Seen The Rain - Alternate Version
# 1    3FHLkTWV2QvC8J0YhX4muT                      Never Seen The Rain
# 2    0bd5hilfGwAKLPehO4SnYP  Never Seen The Rain - Alternate Version
# 3    2nLM2naLp5WUEluvTaajd4  Forever Young - triple j Like A Version
# 4    4ZxGO1BKBNI5GE4oPvwwnn             Dance Monkey - Stripped Back
# ..                      ...                                      ...
# 370  6YyGDbiPej9dX7ybE1fipe                                    Juice
# 371  1PN7NarzTOcrnBMA7uk2wD                          Feels Like This
# 372  2KuYuNYRcsBzQqiI6VkeKf                               How Do You
# 373  0goohndA7o5y28eyo7coUE                         little light one
# 374  5dZ1zMKNM1doAgwcA52SPb                                    Fools
#
#                                       uri  acousticness  danceability  energy  \
# 0    spotify:track:6MYNfMiLwCmA3bRdfzvfcs       0.91800         0.495   0.330
# 1    spotify:track:3FHLkTWV2QvC8J0YhX4muT       0.43000         0.672   0.464
# 2    spotify:track:0bd5hilfGwAKLPehO4SnYP       0.91300         0.508   0.330
# 3    spotify:track:2nLM2naLp5WUEluvTaajd4       0.61600         0.424   0.492
# 4    spotify:track:4ZxGO1BKBNI5GE4oPvwwnn       0.92700         0.627   0.212
# ..                                    ...           ...           ...     ...
# 370  spotify:track:6YyGDbiPej9dX7ybE1fipe       0.00611         0.767   0.889
# 371  spotify:track:1PN7NarzTOcrnBMA7uk2wD       0.95800         0.384   0.165
# 372  spotify:track:2KuYuNYRcsBzQqiI6VkeKf       0.13500         0.820   0.728
# 373  spotify:track:0goohndA7o5y28eyo7coUE       0.05010         0.667   0.703
# 374  spotify:track:5dZ1zMKNM1doAgwcA52SPb       0.35200         0.437   0.737
#
#      instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0            0.000000    0.0973    -8.376       0.0342   76.875    0.330
# 1            0.000000    0.2840    -5.624       0.0370   92.069    0.271
# 2            0.000000    0.0974    -8.367       0.0341   77.133    0.337
# 3            0.000000    0.1350    -9.145       0.1470  136.300    0.231
# 4            0.000000    0.1020    -7.765       0.0460   84.808    0.575
# ..                ...       ...       ...          ...      ...      ...
# 370          0.000000    0.4020    -2.988       0.0963  119.930    0.843
# 371          0.000000    0.1010    -9.601       0.0446   68.469    0.333
# 372          0.000161    0.1370    -8.782       0.1380  125.951    0.530
# 373          0.000871    0.0982    -5.462       0.0325  132.032    0.495
# 374          0.000000    0.1220    -5.914       0.0772  133.116    0.583
#
#      popularity
# 0            14
# 1             4
# 2             3
# 3            51
# 4            50
# ..          ...
# 370          18
# 371          10
# 372          10
# 373          10
# 374           9
#
# [375 rows x 15 columns]

# %%
print(len(df))
final_df = df.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
other_df = df.sort_values('popularity', ascending=False).drop_duplicates('id').sort_index()
print(len(final_df))
print(len(other_df))
# Out:
# 375
# 231
# 375

# %%
df.sort_values(['name', 'popularity'], ascending=False)
# Out:
#                         album  track_number                      id  \
# 16                    Changes            17  2FBpJGt00G0h1q0RHuqaGO
# 4                     Changes             5  16wAOAZ2OkqoIDN7TpChjR
# 94           Believe Acoustic             9  3L7GqCjU0FHXuzhLskcKAL
# 105          Believe Acoustic             9  1b2RMdsbWK80VT7HJ58Ncl
# 46           Purpose (Deluxe)            11  0n8ob8S72lvznoVfiwz4qL
# ..                        ...           ...                     ...
# 161  Believe (Deluxe Edition)             1  3jq6OVXtRqSgeWw4wIzdHA
# 135                   Believe             1  6WgrB8d7GLBGweYLDI6ObR
# 195  Believe (Deluxe Edition)             1  6jT1OCq35aoJ2cTzYrOsZI
# 211  Believe (Deluxe Edition)             1  1S7HydwAAwcl9mLjsUbBYQ
# 0                     Changes             1  5Py8zRKGkZvgHniVVtvNCN
#
#                             name                                   uri  \
# 16   Yummy - Summer Walker Remix  spotify:track:2FBpJGt00G0h1q0RHuqaGO
# 4                          Yummy  spotify:track:16wAOAZ2OkqoIDN7TpChjR
# 94               Yellow Raincoat  spotify:track:3L7GqCjU0FHXuzhLskcKAL
# 105              Yellow Raincoat  spotify:track:1b2RMdsbWK80VT7HJ58Ncl
# 46               Where Are Ü Now  spotify:track:0n8ob8S72lvznoVfiwz4qL
# ..                           ...                                   ...
# 161         All Around The World  spotify:track:3jq6OVXtRqSgeWw4wIzdHA
# 135         All Around The World  spotify:track:6WgrB8d7GLBGweYLDI6ObR
# 195         All Around The World  spotify:track:6jT1OCq35aoJ2cTzYrOsZI
# 211         All Around The World  spotify:track:1S7HydwAAwcl9mLjsUbBYQ
# 0                  All Around Me  spotify:track:5Py8zRKGkZvgHniVVtvNCN
#
#      acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 16         0.3110         0.655   0.578          0.000000    0.1090    -5.711
# 4          0.3450         0.676   0.506          0.000000    0.1180    -6.652
# 94         0.7080         0.783   0.375          0.121000    0.0933    -9.590
# 105        0.7080         0.783   0.375          0.121000    0.0933    -9.590
# 46         0.0342         0.432   0.740          0.000007    0.1400    -5.053
# ..            ...           ...     ...               ...       ...       ...
# 161        0.0190         0.689   0.816          0.000002    0.1810    -3.951
# 135        0.0190         0.689   0.816          0.000002    0.1810    -3.951
# 195        0.0190         0.689   0.816          0.000002    0.1810    -3.951
# 211        0.0190         0.689   0.816          0.000002    0.1810    -3.951
# 0          0.8090         0.566   0.438          0.000000    0.2120    -7.564
#
#      speechiness    tempo  valence  popularity
# 16        0.0534  145.869    0.546          73
# 4         0.0958  145.842    0.497          80
# 94        0.0328  109.953    0.742          44
# 105       0.0328  109.953    0.742          36
# 46        0.0620  139.420    0.193           7
# ..           ...      ...      ...         ...
# 161       0.1780  127.958    0.775          24
# 135       0.1780  127.958    0.775          21
# 195       0.1780  127.958    0.775          13
# 211       0.1780  127.958    0.775           1
# 0         0.0367  117.127    0.692          80
#
# [279 rows x 15 columns]

# %%
from time import sleep
import random

# %%
print('1')
print('2')
print('3')
sleep(random.random() * 10)
print('4')
# Out:
# 1
# 2
# 3
# 4

# %%
sleep(1)
print('done')
# Out:
# done

# %%
random.random() + 1
# Out:
# 1.777832601788769

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time
import numpy as np
import re

# %%
client_id = 'e195c8fc8d724d9cb1c301c45f5afe6b'  # SECRET
client_secret = '833ce97e263f47e7ae1a35313e1baec8'  # SECRET

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

# %%
print('Loading DataFrame...')
top_200 = pd.read_csv('ranking_output.csv')
track_urls = top_200['URL'].unique().tolist()
track_ids = [re.search(r"([^\/]+$)", str(url)).group() for url in track_urls]
# Out:
# Loading DataFrame...

# %%
idx = 0
df = pd.DataFrame()

while idx < len(track_ids):
    track_id_list = track_ids[idx: idx + 100]
#     print('Scraping set {} of {}'.format(int(idx / 100 + 1),
#                                          len(track_ids) / 100))
    
    if int(idx / 100 + 1) < 75:
        idx += 100
        continue
    track_list = ['spotify:track:{}'.format(track_id) for track_id in track_id_list]
    features = sp.audio_features(track_list)
        
    idx += 100
    time.sleep(np.random.uniform(5, 10))

    df_temp = pd.DataFrame.from_dict(features)
    df = pd.concat([df, df_temp])
# Out:
# Scraping set 1 of 685.4
# Scraping set 2 of 685.4
# Scraping set 3 of 685.4
# Scraping set 4 of 685.4
# Scraping set 5 of 685.4
# Scraping set 6 of 685.4
# Scraping set 7 of 685.4
# Scraping set 8 of 685.4
# Scraping set 9 of 685.4
# Scraping set 10 of 685.4
# Scraping set 11 of 685.4
# Scraping set 12 of 685.4
# Scraping set 13 of 685.4
# Scraping set 14 of 685.4
# Scraping set 15 of 685.4
# Scraping set 16 of 685.4
# Scraping set 17 of 685.4
# Scraping set 18 of 685.4
# Scraping set 19 of 685.4
# Scraping set 20 of 685.4
# Scraping set 21 of 685.4
# Scraping set 22 of 685.4
# Scraping set 23 of 685.4
# Scraping set 24 of 685.4
# Scraping set 25 of 685.4
# Scraping set 26 of 685.4
# Scraping set 27 of 685.4
# Scraping set 28 of 685.4
# Scraping set 29 of 685.4
# Scraping set 30 of 685.4
# Scraping set 31 of 685.4
# Scraping set 32 of 685.4
# Scraping set 33 of 685.4
# Scraping set 34 of 685.4
# Scraping set 35 of 685.4
# Scraping set 36 of 685.4
# Scraping set 37 of 685.4
# Scraping set 38 of 685.4
# Scraping set 39 of 685.4
# Scraping set 40 of 685.4
# Scraping set 41 of 685.4
# Scraping set 42 of 685.4
# Scraping set 43 of 685.4
# Scraping set 44 of 685.4
# Scraping set 45 of 685.4
# Scraping set 46 of 685.4
# Scraping set 47 of 685.4
# Scraping set 48 of 685.4
# Scraping set 49 of 685.4
# Scraping set 50 of 685.4
# Scraping set 51 of 685.4
# Scraping set 52 of 685.4
# Scraping set 53 of 685.4
# Scraping set 54 of 685.4
# Scraping set 55 of 685.4
# Scraping set 56 of 685.4
# Scraping set 57 of 685.4
# Scraping set 58 of 685.4
# Scraping set 59 of 685.4
# Scraping set 60 of 685.4
# Scraping set 61 of 685.4
# Scraping set 62 of 685.4
# Scraping set 63 of 685.4
# Scraping set 64 of 685.4
# Scraping set 65 of 685.4
# Scraping set 66 of 685.4
# Scraping set 67 of 685.4
# Scraping set 68 of 685.4
# Scraping set 69 of 685.4
# Scraping set 70 of 685.4
# Scraping set 71 of 685.4
# Scraping set 72 of 685.4
# Scraping set 73 of 685.4
# Scraping set 74 of 685.4
# Scraping set 75 of 685.4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-ee2293b2d838> in <module>
#      16     time.sleep(np.random.uniform(5, 10))
#      17
# ---> 18     df_temp = pd.DataFrame.from_dict(features)
#      19     df = pd.concat([df, df_temp])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1188             raise ValueError("only recognize index or columns for orient")
#    1189
# -> 1190         return cls(data, index=index, columns=columns, dtype=dtype)
#    1191
#    1192     def to_numpy(self, dtype=None, copy=False):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     448                     if is_named_tuple(data[0]) and columns is None:
#     449                         columns = data[0]._fields
# --> 450                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     451                     columns = ensure_index(columns)
#     452
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     465     elif isinstance(data[0], abc.Mapping):
#     466         return _list_of_dict_to_arrays(
# --> 467             data, columns, coerce_float=coerce_float, dtype=dtype
#     468         )
#     469     elif isinstance(data[0], ABCSeries):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_of_dict_to_arrays(data, columns, coerce_float, dtype)
#     561         types = (dict, OrderedDict) if PY36 else OrderedDict
#     562         sort = not any(isinstance(d, types) for d in data)
# --> 563         columns = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#     564
#     565     # assure that they are of the base dict class and not of derived
#
# pandas\_libs\lib.pyx in pandas._libs.lib.fast_unique_multiple_list_gen()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in <genexpr>(.0)
#     558     """
#     559     if columns is None:
# --> 560         gen = (list(x.keys()) for x in data)
#     561         types = (dict, OrderedDict) if PY36 else OrderedDict
#     562         sort = not any(isinstance(d, types) for d in data)
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
idx
# Out:
# 7500

# %%
pd.DataFrame.from_dict(features[62:64])
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.476   0.720    1    -4.357     0       0.0346        0.0102
# 1         0.583   0.283   11    -5.228     1       0.0312        0.8900
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0                 0    0.0639    0.218  99.054  audio_features
# 1                 0    0.1300    0.387  62.642  audio_features
#
#                        id                                   uri  \
# 0  45wBTYlOx3FsuFluuuRRQh  spotify:track:45wBTYlOx3FsuFluuuRRQh
# 1  0b0hbaQZnkFDOGjOUkIbUK  spotify:track:0b0hbaQZnkFDOGjOUkIbUK
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/45wBTYlOx3Fs...
# 1  https://api.spotify.com/v1/tracks/0b0hbaQZnkFD...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/45wB...       236133
# 1  https://api.spotify.com/v1/audio-analysis/0b0h...       168547
#
#    time_signature
# 0               4
# 1               4

# %%
for idx in range(len(track_ids)):
    if track_ids[idx] == '0b0hbaQZnkFDOGjOUkIbUK':
        print(idx)
# Out:
# 7463

# %%
track_ids[7464]
# Out:
# '3uMIfxV8q5tPTWzJh8s6Mk'

# %%
sp.audio_features(['spotify:track:{}'.format(track_ids[7464])])
# Out:
# [None]

# %%
features[64]

# %%
features[63:66]
# Out:
# [{'danceability': 0.583,
#   'energy': 0.283,
#   'key': 11,
#   'loudness': -5.228,
#   'mode': 1,
#   'speechiness': 0.0312,
#   'acousticness': 0.89,
#   'instrumentalness': 0,
#   'liveness': 0.13,
#   'valence': 0.387,
#   'tempo': 62.642,
#   'type': 'audio_features',
#   'id': '0b0hbaQZnkFDOGjOUkIbUK',
#   'uri': 'spotify:track:0b0hbaQZnkFDOGjOUkIbUK',
#   'track_href': 'https://api.spotify.com/v1/tracks/0b0hbaQZnkFDOGjOUkIbUK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0b0hbaQZnkFDOGjOUkIbUK',
#   'duration_ms': 168547,
#   'time_signature': 4},
#  None,
#  {'danceability': 0.315,
#   'energy': 0.975,
#   'key': 4,
#   'loudness': -3.21,
#   'mode': 1,
#   'speechiness': 0.0703,
#   'acousticness': 0.000558,
#   'instrumentalness': 0.00145,
#   'liveness': 0.467,
#   'valence': 0.435,
#   'tempo': 138.215,
#   'type': 'audio_features',
#   'id': '03QZPaiw1N94aAFDv7k5Em',
#   'uri': 'spotify:track:03QZPaiw1N94aAFDv7k5Em',
#   'track_href': 'https://api.spotify.com/v1/tracks/03QZPaiw1N94aAFDv7k5Em',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/03QZPaiw1N94aAFDv7k5Em',
#   'duration_ms': 322947,
#   'time_signature': 4}]

# %%
for idx in range(len(features)):
    if features[idx] is None:
        print(idx)
# Out:
# 64

# %%
corrected_features = []
for i in range(len(features)):
    if features[i] is None:
        print(i)
        print('No data for track {}'.format(track_ids[7400 + i]))
    else:
        corrected_features.append(features[i])
# Out:
# 64
# No data for track 3uMIfxV8q5tPTWzJh8s6Mk

# %%
for idx in range(len(track_ids)):
    if track_ids[idx] == '3uMIfxV8q5tPTWzJh8s6Mk':
        print(idx)
# Out:
# 7464

# %%
len(new_dict)
# Out:
# 99

# %%
new_dict[63:66]
# Out:
# [{'danceability': 0.583,
#   'energy': 0.283,
#   'key': 11,
#   'loudness': -5.228,
#   'mode': 1,
#   'speechiness': 0.0312,
#   'acousticness': 0.89,
#   'instrumentalness': 0,
#   'liveness': 0.13,
#   'valence': 0.387,
#   'tempo': 62.642,
#   'type': 'audio_features',
#   'id': '0b0hbaQZnkFDOGjOUkIbUK',
#   'uri': 'spotify:track:0b0hbaQZnkFDOGjOUkIbUK',
#   'track_href': 'https://api.spotify.com/v1/tracks/0b0hbaQZnkFDOGjOUkIbUK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0b0hbaQZnkFDOGjOUkIbUK',
#   'duration_ms': 168547,
#   'time_signature': 4},
#  {'danceability': 0.315,
#   'energy': 0.975,
#   'key': 4,
#   'loudness': -3.21,
#   'mode': 1,
#   'speechiness': 0.0703,
#   'acousticness': 0.000558,
#   'instrumentalness': 0.00145,
#   'liveness': 0.467,
#   'valence': 0.435,
#   'tempo': 138.215,
#   'type': 'audio_features',
#   'id': '03QZPaiw1N94aAFDv7k5Em',
#   'uri': 'spotify:track:03QZPaiw1N94aAFDv7k5Em',
#   'track_href': 'https://api.spotify.com/v1/tracks/03QZPaiw1N94aAFDv7k5Em',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/03QZPaiw1N94aAFDv7k5Em',
#   'duration_ms': 322947,
#   'time_signature': 4},
#  {'danceability': 0.266,
#   'energy': 0.934,
#   'key': 0,
#   'loudness': -2.28,
#   'mode': 0,
#   'speechiness': 0.0929,
#   'acousticness': 0.171,
#   'instrumentalness': 0.0223,
#   'liveness': 0.288,
#   'valence': 0.07,
#   'tempo': 110.268,
#   'type': 'audio_features',
#   'id': '15J419FaKaBT7bYJmpLDpf',
#   'uri': 'spotify:track:15J419FaKaBT7bYJmpLDpf',
#   'track_href': 'https://api.spotify.com/v1/tracks/15J419FaKaBT7bYJmpLDpf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15J419FaKaBT7bYJmpLDpf',
#   'duration_ms': 327920,
#   'time_signature': 4}]

# %%
with open('feature_output.csv', 'w', newline='', encoding="utf-8") as f:
    df.to_csv(f, index=False)

# %%
track_id_list = track_ids[idx: idx + 100]

# %%
[item for item in features if item is not None][63:66]
# Out:
# [{'danceability': 0.583,
#   'energy': 0.283,
#   'key': 11,
#   'loudness': -5.228,
#   'mode': 1,
#   'speechiness': 0.0312,
#   'acousticness': 0.89,
#   'instrumentalness': 0,
#   'liveness': 0.13,
#   'valence': 0.387,
#   'tempo': 62.642,
#   'type': 'audio_features',
#   'id': '0b0hbaQZnkFDOGjOUkIbUK',
#   'uri': 'spotify:track:0b0hbaQZnkFDOGjOUkIbUK',
#   'track_href': 'https://api.spotify.com/v1/tracks/0b0hbaQZnkFDOGjOUkIbUK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0b0hbaQZnkFDOGjOUkIbUK',
#   'duration_ms': 168547,
#   'time_signature': 4},
#  {'danceability': 0.315,
#   'energy': 0.975,
#   'key': 4,
#   'loudness': -3.21,
#   'mode': 1,
#   'speechiness': 0.0703,
#   'acousticness': 0.000558,
#   'instrumentalness': 0.00145,
#   'liveness': 0.467,
#   'valence': 0.435,
#   'tempo': 138.215,
#   'type': 'audio_features',
#   'id': '03QZPaiw1N94aAFDv7k5Em',
#   'uri': 'spotify:track:03QZPaiw1N94aAFDv7k5Em',
#   'track_href': 'https://api.spotify.com/v1/tracks/03QZPaiw1N94aAFDv7k5Em',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/03QZPaiw1N94aAFDv7k5Em',
#   'duration_ms': 322947,
#   'time_signature': 4},
#  {'danceability': 0.266,
#   'energy': 0.934,
#   'key': 0,
#   'loudness': -2.28,
#   'mode': 0,
#   'speechiness': 0.0929,
#   'acousticness': 0.171,
#   'instrumentalness': 0.0223,
#   'liveness': 0.288,
#   'valence': 0.07,
#   'tempo': 110.268,
#   'type': 'audio_features',
#   'id': '15J419FaKaBT7bYJmpLDpf',
#   'uri': 'spotify:track:15J419FaKaBT7bYJmpLDpf',
#   'track_href': 'https://api.spotify.com/v1/tracks/15J419FaKaBT7bYJmpLDpf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15J419FaKaBT7bYJmpLDpf',
#   'duration_ms': 327920,
#   'time_signature': 4}]

# %%
for idx in range(len(track_ids)):
    if track_ids[idx] == 'nan':
        print(idx)
# Out:
# 13299

# %%
top_200 = pd.read_csv('ranking_output.csv')
track_urls = top_200['URL'].unique().tolist()
track_ids = [re.search(r"([^\/]+$)", str(url)).group() for url in track_urls]

# %%
track_ids[13299]
# Out:
# 'nan'

# %%
track_urls[13299]
# Out:
# nan

# %%
top_200[top_200['URL']if isinstance(o, str):]
# Out:
# Empty DataFrame
# Columns: [Position, Track Name, Artist, Streams, URL, Country, Date]
# Index: []

# %%
track_urls[13290:13305]
# Out:
# ['https://open.spotify.com/track/2i2JtDSr6GbkRpTToH15SN',
#  'https://open.spotify.com/track/30f7TNgvsS1AWtyuVqMucH',
#  'https://open.spotify.com/track/4j5WelE5mkf9A2jmts729h',
#  'https://open.spotify.com/track/5e0bzcsI1khimLSJhddHdS',
#  'https://open.spotify.com/track/3NhRXvQITM1OFwSpsMOYxx',
#  'https://open.spotify.com/track/75BkOj9E4rIerxcXwFMcsX',
#  'https://open.spotify.com/track/3mbGX2yy83BtCiPO59mE5r',
#  'https://open.spotify.com/track/2bHRnMtpXMUmzDHZrAyxne',
#  'https://open.spotify.com/track/61u7CLDwOodpdENZTTsxUd',
#  nan,
#  'https://open.spotify.com/track/1CqRXv6FUvvuCYailCqnGR',
#  'https://open.spotify.com/track/0L1IszgjzIZRBENyHJTQms',
#  'https://open.spotify.com/track/0b8PKDeFc2T5u9cRbLLv2r',
#  'https://open.spotify.com/track/0Nq7JtZtjHjJ2fprzzgwio',
#  'https://open.spotify.com/track/2UOyQB26wSQzM0jiTcUg50']

# %%
top_200[top_200['URL'].apply(lambda x: not isinstance(x, str))]
# Out:
#           Position Track Name Artist  Streams  URL Country        Date
# 1077734        135        NaN    NaN     6044  NaN      at  2019-05-17
# 1607603          8        NaN    NaN     3244  NaN      bg  2020-02-07
# 1607605         10        NaN    NaN     3131  NaN      bg  2020-02-07
# 1607609         14        NaN    NaN     3045  NaN      bg  2020-02-07
# 1607616         21        NaN    NaN     2333  NaN      bg  2020-02-07
# 1607620         25        NaN    NaN     2197  NaN      bg  2020-02-07
# 1607624         29        NaN    NaN     2094  NaN      bg  2020-02-07
# 1607630         35        NaN    NaN     1906  NaN      bg  2020-02-07
# 1607637         42        NaN    NaN     1713  NaN      bg  2020-02-07
# 3275247         30        NaN    NaN     5740  NaN      cz  2018-10-17
# 3275276         59        NaN    NaN     4184  NaN      cz  2018-10-17
# 3275285         68        NaN    NaN     3876  NaN      cz  2018-10-17
# 3275309         92        NaN    NaN     3210  NaN      cz  2018-10-17
# 3544120        103        NaN    NaN   106195  NaN      de  2019-05-17
# 5434758         81        NaN    NaN     3397  NaN      hk  2017-11-25
# 5435064        187        NaN    NaN     1997  NaN      hk  2017-11-26
# 6982956         83        NaN    NaN    78353  NaN      it  2020-02-05
# 7881487         23        NaN    NaN   123366  NaN      nl  2017-06-30
# 7881526         62        NaN    NaN    72756  NaN      nl  2017-06-30
# 7901743         79        NaN    NaN    42943  NaN      nl  2017-10-09
# 7902015        151        NaN    NaN    22791  NaN      nl  2017-10-10
# 10247740       102        NaN    NaN     6402  NaN      sg  2017-11-25
# 10248026       188        NaN    NaN     4197  NaN      sg  2017-11-26
# 10459036        39        NaN    NaN     1808  NaN      sk  2018-10-17
# 10459112       115        NaN    NaN     1017  NaN      sk  2018-10-17
